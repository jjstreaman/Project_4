# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load in the dataframe

# %%
df = pd.read_csv('data/McDonald_s_Reviews.csv', encoding='latin-1')
df
# Out:
#        reviewer_id  store_name              category  \
# 0                1  McDonald's  Fast food restaurant
# 1                2  McDonald's  Fast food restaurant
# 2                3  McDonald's  Fast food restaurant
# 3                4  McDonald's  Fast food restaurant
# 4                5  McDonald's  Fast food restaurant
# ...            ...         ...                   ...
# 33391        33392  McDonald's  Fast food restaurant
# 33392        33393  McDonald's  Fast food restaurant
# 33393        33394  McDonald's  Fast food restaurant
# 33394        33395  McDonald's  Fast food restaurant
# 33395        33396  McDonald's  Fast food restaurant
#
#                                            store_address  latitude   \
# 0      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718
# 1      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718
# 2      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718
# ...

# %% [markdown]
# Explore data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33396 entries, 0 to 33395
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewer_id    33396 non-null  int64
#  1   store_name     33396 non-null  object
#  2   category       33396 non-null  object
#  3   store_address  33396 non-null  object
#  4   latitude       32736 non-null  float64
#  5   longitude      32736 non-null  float64
#  6   rating_count   33396 non-null  object
#  7   review_time    33396 non-null  object
#  8   review         33396 non-null  object
#  9   rating         33396 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.5+ MB

# %%
df['category'].value_counts()
# Out:
# category
# Fast food restaurant    33396
# Name: count, dtype: int64

# %%
df['category'].unique()
# Out:
# array(['Fast food restaurant'], dtype=object)

# %%
df['rating'].value_counts()
# Out:
# rating
# 5 stars    10274
# 1 star      9431
# 4 stars     5787
# 3 stars     4818
# 2 stars     3086
# Name: count, dtype: int64

# %%
df['store_name'].unique()
# Out:
# array(["McDonald's", "ýýýMcDonald's"], dtype=object)

# %% [markdown]
# 'category', 'store_name', 'reviewer_id' irreleveant, will drop.

# %%
df = df.drop(['category', 'store_name', 'reviewer_id'], axis=1)
df.head()
# Out:
#                                        store_address  latitude   longitude  \
# 0  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 1  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 2  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 3  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 4  13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
#
#   rating_count   review_time  \
# 0        1,240  3 months ago
# 1        1,240    5 days ago
# 2        1,240    5 days ago
# 3        1,240   a month ago
# 4        1,240  2 months ago
#
#                                               review   rating
# 0  Why does it look like someone spit on my food?...   1 star
# 1  It'd McDonalds. It is what it is as far as the...  4 stars
# 2  Made a mobile order got to the speaker and che...   1 star
# 3  My mc. Crispy chicken sandwich was ï¿½ï¿½ï¿½ï¿...  5 stars
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33396 entries, 0 to 33395
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   store_address  33396 non-null  object
#  1   latitude       32736 non-null  float64
#  2   longitude      32736 non-null  float64
#  3   rating_count   33396 non-null  object
#  4   review_time    33396 non-null  object
#  5   review         33396 non-null  object
#  6   rating         33396 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# Some NaN values with 'latitude' and 'longitude'.

# %%
#lat_nan = df[df['latitude'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#df['latitude'].head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(df.columns)
# Out:
# Index(['store_address', 'latitude ', 'longitude', 'rating_count',
#        'review_time', 'review', 'rating'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['store_address', 'latitude', 'longitude', 'rating_count', 'review_time',
#        'review', 'rating'],
#       dtype='object')

# %%
df['latitude'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 33391    False
# 33392    False
# 33393    False
# 33394    False
# 33395    False
# Name: latitude, Length: 33396, dtype: bool

# %%
rows_with_nan = df[df['latitude'].isna()]

# %%
print(rows_with_nan)
# Out:
#                                            store_address  latitude  longitude  \
# 22141  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
# 22142  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
# 22143  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
# 22144  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
# 22145  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
# ...                                                  ...       ...        ...
# 27719  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
# 27720  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
# 27721  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
# 27722  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
# 27723  2476 Kalï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿...       NaN        NaN
#
# ...

# %% [markdown]
# 660 NaNs for Lat&Long, will drop.

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32736 entries, 0 to 33395
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   store_address  32736 non-null  object
#  1   latitude       32736 non-null  float64
#  2   longitude      32736 non-null  float64
#  3   rating_count   32736 non-null  object
#  4   review_time    32736 non-null  object
#  5   review         32736 non-null  object
#  6   rating         32736 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.0+ MB

# %%
df[['store_address', 'latitude', 'longitude']]
# Out:
#                                            store_address   latitude  longitude
# 0      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 1      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 2      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 3      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# 4      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718 -97.792874
# ...                                                  ...        ...        ...
# 33391  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000 -80.189098
# 33392  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000 -80.189098
# 33393  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000 -80.189098
# 33394  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000 -80.189098
# 33395  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000 -80.189098
#
# ...

# %%
unique_rows = df[['store_address', 'latitude', 'longitude']].drop_duplicates()
unique_rows
# Out:
#                                            store_address   latitude  \
# 0      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718
# 800    1698 US-209, Brodheadsville, PA 18322, United ...  40.922081
# 1828   72-69 Kissena Blvd, Queens, NY 11367, United S...  40.727401
# 2968      429 7th Ave, New York, NY 10001, United States  40.750506
# 4108     724 Broadway, New York, NY 10003, United States  40.729126
# 5248     160 Broadway, New York, NY 10038, United States  40.709375
# 5251   555 13th St NW, Washington, DC 20004, United S...  38.896980
# 5254   10451 Santa Monica Blvd, Los Angeles, CA 90025...  34.056593
# 5257   114 Delancey St, New York, NY 10002, United St...  40.718838
# 5260   5920 Balboa Ave, San Diego, CA 92111, United S...  32.820654
# 5810     262 Canal St, New York, NY 10013, United States  40.718514
# 6080      490 8th Ave, New York, NY 10001, United States  40.752529
# 6950   550 Lawrence Expy, Sunnyvale, CA 94086, United...  37.385495
# ...

# %%
len(unique_rows)
# Out:
# 39

# %% [markdown]
# 39 unique combos of address, lat & long

# %% [markdown]
# Change 'rating' from object to float

# %%
df['rating'] = df['rating'].str.extract('(\d+)').astype(float)
df['rating'].value_counts()
# Out:
# <ipython-input-23-0f302563f899>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].str.extract('(\d+)').astype(float)
# rating
# 5.0    10059
# 1.0     9305
# 4.0     5646
# 3.0     4706
# 2.0     3020
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32736 entries, 0 to 33395
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   store_address  32736 non-null  object
#  1   latitude       32736 non-null  float64
#  2   longitude      32736 non-null  float64
#  3   rating_count   32736 non-null  object
#  4   review_time    32736 non-null  object
#  5   review         32736 non-null  object
#  6   rating         32736 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 2.0+ MB

# %%
print(df['rating'].dtype)
# Out:
# float64

# %%
df['rating_count']
# Out:
# 0        1,240
# 1        1,240
# 2        1,240
# 3        1,240
# 4        1,240
#          ...
# 33391    2,810
# 33392    2,810
# 33393    2,810
# 33394    2,810
# 33395    2,810
# Name: rating_count, Length: 32736, dtype: object

# %%
df['rating_count'].value_counts()
# Out:
# rating_count
# 2,810     1140
# 2,193     1140
# 2,052     1140
# 1,670     1140
# 2,658     1140
# 5,468     1140
# 1,618     1140
# 1,564     1100
# 2,365     1030
# 1,028     1028
# 998        998
# 1,795      960
# 5,567      950
# 933        943
# 1,406      926
# 3,243      890
# 3,902      870
# 957        850
# 1,240      800
# 1,562      800
# 5,566      770
# 1,454      751
# 1,794      750
# 5,466      750
# 1,861      710
# 1,269      680
# 1,159      680
# 1,460      635
# 1,306      610
# 595        602
# 3,380      590
# 4,922      570
# 1,617      560
# 2,614      550
# 550        550
# 2,657      510
# 2,722      481
# 19,671     460
# 2,808      430
# 3,196      270
# 3,381      230
# 1,565      190
# 999        170
# 263         60
# 19,682      30
# 1,307       10
# 2,348        3
# 2,251        3
# 1,542        3
# 5,186        3
# Name: count, dtype: int64

# %% [markdown]
# 'rating_count' = # ratings for the store. could use for further analysis.

# %% [markdown]
# 'review_time' could be used to see how reviews change over time

# %% [markdown]
# drop 'store_name', it's unneccessary.

# %%
df_cleaned = df
df_cleaned
# Out:
#                                            store_address   latitude  \
# 0      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718
# 1      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718
# 2      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718
# 3      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718
# 4      13749 US-183 Hwy, Austin, TX 78750, United States  30.460718
# ...                                                  ...        ...
# 33391  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000
# 33392  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000
# 33393  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000
# 33394  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000
# 33395  3501 Biscayne Blvd, Miami, FL 33137, United St...  25.810000
#
#        longitude rating_count   review_time  \
# 0     -97.792874        1,240  3 months ago
# 1     -97.792874        1,240    5 days ago
# ...

# %%
df_cleaned.to_csv('data/cleaned.csv')
